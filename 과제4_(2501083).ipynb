# %%
#25
keys = input().split()
values = list(map(int, input().split()))
result_dict = dict(zip(keys, values))
print(result_dict)
# Out:
# {'alpha': 30, 'bravo': 40, 'charlie': 50, 'delta': 60, 'echo': 70, 'foxtrot': 80, 'golf': 90}

# %%
#26
park = {'korean': 94, 'english': 91, 'mathematics': 89, 'science': 83}
print(f"영어: {park['english']}")
print(f"과학: {park['science']}")
# Out:
# 영어: 91
# 과학: 83

# %%
#27
kim = {'korean': 94, 'english': 91, 'mathematics': 89, 'science': 83}
for subject in kim.keys():
    kim[subject] = 100
print(kim)
# Out:
# {'korean': 100, 'english': 100, 'mathematics': 100, 'science': 100}

# %%
#28
lee = {'korean': 94, 'english': 91, 'mathematics': 89, 'science': 83}
if 'english' in lee:
    del lee['english']
print(lee)
# Out:
# {'korean': 94, 'mathematics': 89, 'science': 83}

# %%
#29
lim = {'korean': 94, 'english': 91, 'mathematics': 89, 'science': 83}
for key, value in lim.items():
    print(key, value)
# Out:
# korean 94
# english 91
# mathematics 89
# science 83

# %%
#30
cchoi = {'korean': 94, 'english': 91, 'mathematics': 89, 'science': 83}
high_scores_dict = {key: value for key, value in choi.items() if value >= 90}
print(list(high_scores_dict.keys()))
# Out:
# ['korean', 'english']

# %%
#31
yoo = {'korean': 94, 'english': 91, 'mathematics': 89, 'science': 83}
scores = yoo.values()
average = sum(scores) / len(yoo)
print(f"평균: {average}")
# Out:
# 평균: 89.25
